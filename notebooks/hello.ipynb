# %% [markdown]
# # Hello — smoke test
#
# Valida que o ambiente (`requirements.txt`) está ok antes dos notebooks de dengue.
#
# Registre no [`DIARIO.md`](../DIARIO.md) quando rodar pela primeira vez.

# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import sklearn

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

print("Python:", sys.version.split()[0])
print("pandas:", pd.__version__)
print("sklearn:", sklearn.__version__)
print("ROOT:", ROOT)
print("data/raw:", (ROOT / "data" / "raw").exists())
print("OK — ambiente pronto.")
